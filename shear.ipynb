# %%
import matplotlib.pyplot as plt
from matplotlib.tri import  TriAnalyzer,LinearTriInterpolator, Triangulation
from matplotlib.collections import PolyCollection
import numpy as np
import ipywidgets as widgets
import os 

# Direction labels
DIRS = ["x", "y", "z"]
# Path to the data
PATH = "data/Cetex_TC1000_Iosipescu"
# Cross section area
AREA = 1.89 * 11.4

# %% [markdown]
# # Load data files

# %% [markdown]
# The DIC results are stored in comma seperated files (*.csv) with this structure:
# ```
# # Units: length:mm angle:deg time:s force:N
# # Stage: Stufe 1
# stage;index;relative_time;date
# "Stufe 1";1;0.0000;"2024-01-29T15:34:18.319"
# # Name : Analogeingang 0
# force;untransformed;transformed
# 7.1754;0.0024;7.1754
# # Name : Flächenkomponente 3
# id;x;y;z
# 0;0.8973;16.1050;0.0009
# 1;2.2069;16.8182;-0.0003
# ...
# ```
#
# Therefore, we begin by reading the files to store forces and all facet positions in lists. It may happen, that a facet was lost and the number of facets does not agree with the initial image. In that case, we simply drop the frame.

# %%
# We store the forces and positions in dictionaries
forces = []
positions = []

# Number of files to read
n_files = len([f for f in os.listdir(PATH) if os.path.isfile(os.path.join(PATH, f))])

# Iterate over files
for n in range(1, n_files):
    dic_file = f"{PATH}/Flächenkomponente 3_{n:04d}.csv"
    # Read force from file
    with open(dic_file) as f:
        for i, line in enumerate(f):
            if i == 6:
                force = float(line.split(";")[0])
            if i == 10:
                break
        if i < 10:
            print(f"Dropping {dic_file} due to missing data.")
            continue
    # Read positions from file
    pos = np.loadtxt(dic_file, skiprows=9, delimiter=";")[:, 1:4]
    if len(positions) > 0:
        if pos.shape[0] != positions[0].shape[0]:
            print(f"Dropping {dic_file} due to lost facets.")
            continue
    # Append to lists
    forces.append(force)
    positions.append(pos)


N = len(forces)
# Out:
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0085.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0087.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0088.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0089.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0090.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0091.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0092.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0093.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0094.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0095.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0096.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0097.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0098.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0099.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0100.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0101.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0102.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0103.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0104.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0105.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0106.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0107.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0108.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0109.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0111.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0112.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0115.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0119.csv due to missing data.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0144.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0147.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0149.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0150.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0151.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0152.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0153.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0154.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0155.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0156.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0157.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0158.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0159.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0160.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0161.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0162.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0163.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0164.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0165.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0166.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0167.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0195.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0196.csv due to missing data.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0199.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0217.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0218.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0219.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0220.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0221.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0222.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0223.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0226.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0227.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0228.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0229.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0230.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0231.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0232.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0233.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0234.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0236.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0237.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0238.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0244.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0245.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0246.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0247.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0248.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0249.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0250.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0251.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0252.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0253.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0254.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0255.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0256.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0257.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0258.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0259.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0260.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0261.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0262.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0263.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0264.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0265.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0266.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0267.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0268.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0269.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0270.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0271.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0272.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0273.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0274.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0275.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0276.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0277.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0278.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0279.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0280.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0281.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0360.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0408.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0519.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0521.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0522.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0523.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0524.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0525.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0526.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0527.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0528.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0529.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0530.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0536.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0537.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0539.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0545.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0547.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0554.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0565.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0566.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0568.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0569.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0573.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0577.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0578.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0579.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0580.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0581.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0582.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0583.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0584.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0585.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0587.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0588.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0589.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0590.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0591.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0592.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0594.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0595.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0596.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0597.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0598.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0599.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0600.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0601.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0602.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0603.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0606.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0608.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0609.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0610.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0611.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0612.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0613.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0614.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0615.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0616.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0617.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0618.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0620.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0621.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0622.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0623.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0624.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0625.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0626.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0627.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0628.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0629.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0630.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0631.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0632.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0633.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0636.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0637.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0638.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0639.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0640.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0641.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0642.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0643.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0644.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0645.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0646.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0649.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0650.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0651.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0652.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0654.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0655.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0656.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0657.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0658.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0659.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0660.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0661.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0662.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0663.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0664.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0665.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0666.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0667.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0668.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0669.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0670.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0671.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0672.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0673.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0674.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0675.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0676.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0677.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0678.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0679.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0680.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0681.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0682.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0683.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0684.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0685.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0686.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0687.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0688.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0689.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0690.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0691.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0692.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0693.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0694.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0695.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0696.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0697.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0698.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0699.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0700.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0701.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0702.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0703.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0704.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0705.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0706.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0707.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0708.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0709.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0710.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0711.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0712.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0713.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0714.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0715.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0716.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0717.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0718.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0719.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0720.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0721.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0722.csv due to lost facets.
# Dropping data/Cetex_TC1000_Iosipescu/Flächenkomponente 3_0723.csv due to lost facets.

# %% [markdown]
# # Visualize displacement data as interactive plot

# %%
def plot_disp(n):
    pos = positions[n]
    disp = pos - positions[0]
    fig, ax = plt.subplots(ncols=3, nrows=1, figsize=(10, 5))
    for i in range(3):
        contour = ax[i].tricontourf(pos[:, 0], pos[:, 1], disp[:, i], levels=20)
        ax[i].set_xlabel("x in mm")
        ax[i].set_ylabel("y in mm")
        ax[i].set_title(f"Displacement in {DIRS[i]} in mm")
        ax[i].axis("equal")
        plt.colorbar(contour, ax=ax[i])
    plt.tight_layout()
    plt.show()


widgets.interact(plot_disp,n=widgets.IntSlider(value=N-1, min=0, max=N-1, step=1))
# Out:
# interactive(children=(IntSlider(value=453, description='n', max=453), Output()), _dom_classes=('widget-interac…
# <function __main__.plot_disp(n)>

# %% [markdown]
# # Triangulate the displacement data to compute gradients

# %%
# Build a triangulation
pos = positions[0]
tri = Triangulation(pos[:,0], pos[:,1])

# Mask low quality elements at the boundary
mask = TriAnalyzer(tri).get_flat_tri_mask(.3)
tri.set_mask(mask)

# Compute nodes and centers of each triangle
tria_nodes = pos[tri.triangles]
center_x = np.mean(tri.x[tri.triangles], axis=1)
center_y = np.mean(tri.y[tri.triangles], axis=1)

# %%
eps_xx = []
eps_yy = []
eps_xy = []

for pos in positions:
    disp = pos - positions[0]

    # Compute displacement gradient
    u_x = LinearTriInterpolator(tri, disp[:,0])
    u_y = LinearTriInterpolator(tri, disp[:,1])
    (u_xx, u_xy) = u_x.gradient(center_x, center_y)
    (u_yx, u_yy) = u_y.gradient(center_x, center_y)

    # Compute strain
    eps_xx.append(u_xx)
    eps_yy.append(u_yy)
    eps_xy.append(0.5 * (u_xy + u_yx))

# %%
# Define region of interest 
roi = (center_x>7.0) & (center_x<8.5)

# %%
def plot_strain(n):
    pos = positions[n]
    tria_nodes = pos[tri.triangles]
    # Plot strains
    fig, ax = plt.subplots(ncols=3, nrows=1, figsize=(15, 5))
    props ={"ε_xx": eps_xx[n],"ε_xy": eps_xy[n], "ε_yy": eps_yy[n]}
    for i, (lbl, eps) in enumerate(props.items()):
        alpha = 0.4*roi+0.6
        pc = PolyCollection(tria_nodes[:,:,0:2], array=eps, cmap="magma", alpha=alpha)
        contour = ax[i].add_collection(pc)
        ax[i].set_title(lbl)
        ax[i].triplot(tri, color="k", lw=0.1)
        ax[i].set_xlabel("x in mm")
        ax[i].set_ylabel("y in mm")
        ax[i].axis("equal")
        plt.colorbar(contour, ax=ax[i])
    plt.tight_layout()
    plt.show()

widgets.interact(plot_strain,n=widgets.IntSlider(value=N-1, min=1, max=N-1, step=1))
# Out:
# interactive(children=(IntSlider(value=453, description='n', max=453, min=1), Output()), _dom_classes=('widget-…
# <function __main__.plot_strain(n)>

# %% [markdown]
# # Plot stress-strain diagram

# %%
# Average strains and set units to %
eps_xx_avg = np.array([e[roi].mean() for e in eps_xx])
eps_yy_avg = np.array([e[roi].mean() for e in eps_yy])
eps_xy_avg = -np.array([e[roi].mean() for e in eps_xy])
sigma_xy_avg = np.array(forces) / AREA

# Linear regression with zero intercept
mask = eps_xy_avg<0.005
A = np.vstack([eps_xy_avg[mask], np.zeros(len(eps_xy_avg[mask]))]).T
G, _ = np.linalg.lstsq(A, sigma_xy_avg[mask], rcond=None)[0]
eps_xy_val = np.linspace(0, eps_xy_avg[mask].max(), 100)

# Plot stress-strain curve
plt.plot(100*eps_xy_avg, sigma_xy_avg, "o", markersize=1, label="Data")
plt.plot(100*eps_xy_val, G * eps_xy_val, "-k", label=f"G = {G:.0f} MPa")
plt.xlim(left=0)
plt.ylim(bottom=0)
plt.xlabel("Strain ε_yy in %")
plt.ylabel("Stress σ_yy in MPa")
plt.grid("on")
plt.legend()
plt.show()
